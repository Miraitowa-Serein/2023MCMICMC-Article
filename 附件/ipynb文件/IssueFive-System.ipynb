# %%
import pandas as pd

# %%
data1=pd.read_excel("Data\\First\\New\\201404070532.xlsx",sheet_name="201404070532")
data2=pd.read_excel("Data\\First\\New\\201404071917.xlsx",sheet_name="201404071917")
data3=pd.read_excel("Data\\First\\New\\201404080617.xlsx",sheet_name="201404080617")
data4=pd.read_excel("Data\\First\\New\\201404081034.xlsx",sheet_name="201404081034")
data5=pd.read_excel("Data\\First\\New\\201404090110.xlsx",sheet_name="201404090110")
data6=pd.read_excel("Data\\First\\New\\201404091701.xlsx",sheet_name="201404091701")
data7=pd.read_excel("Data\\First\\New\\201404100843.xlsx",sheet_name="201404100843")
data8=pd.read_excel("Data\\First\\New\\201404101159.xlsx",sheet_name="201404101159")
dataAll=pd.read_excel("Data\\First\\New\\汇总.xlsx",sheet_name="Sheet1")

# %%
def MaxFactor(data):
    data['G值']=data[['着陆G值0.1秒','着陆G值0.2秒','着陆G值0.3秒','着陆G值0.4秒','着陆G值0.5秒',
                      '着陆G值0.6秒','着陆G值0.7秒','着陆G值0.8秒','着陆G值0.9秒','着陆G值1秒']].max(axis=1)
    data['姿态']=data[['姿态（俯仰角）','姿态（俯仰角）.1','姿态（俯仰角）.2','姿态（俯仰角）.3','姿态（俯仰角）.4']].max(axis=1)
    data['杆量']=data[['杆量','杆量.1','杆量.2','杆量.3','杆量.4']].max(axis=1)
    data['坡度']=data[['坡度（左负右正）','坡度（左负右正）.1']].max(axis=1)
    data['盘量']=data[['盘量','盘量.1','盘量.2','盘量.3','盘量.4']].max(axis=1)
    data['左油门杆位置']=data[['左发油门杆位置（角度）','左发油门杆位置（角度）.1']].max(axis=1)
    data['右油门杆位置']=data[['右发油门杆位置（角度）','右发油门杆位置（角度）.1']].max(axis=1)
    return data

# %%
def FactorSelect(data):
    New=data[['具体时间',
              '计算空速','G值','姿态','杆量','坡度','盘量',
              '下滑道偏差（C）','下滑道偏差（L）','下滑道偏差（R）',
              '航向道偏差（C）','航向道偏差（L）','航向道偏差（R）',
              '俯仰角率','下降率','RUDD位置','左油门杆位置','右油门杆位置']]
    return New

# %%
dataAI=MaxFactor(dataAll)

# %%
dataAF=FactorSelect(dataAI)

# %%
dataAF
# Out:
#             具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0        5:32:48  30.0  1.0156 -0.3516 -0.0010  0.0879  0.0115     -0.49
# 1        5:32:49  30.0  1.0273 -0.3516 -0.0010  0.0879  0.0115     -0.47
# 2        5:32:50  30.0  1.0117 -0.3516 -0.0010  0.0879  0.0104      0.08
# 3        5:32:51  30.0  1.0273 -0.3516 -0.0010  0.0879  0.0104     -0.17
# 4        5:32:52  30.0  1.0156 -0.3516 -0.0010  0.0879  0.0115     -0.05
# ...          ...   ...     ...     ...     ...     ...     ...       ...
# 205088  14:04:20  30.0  1.0078 -0.7031 -0.0021  0.0879  0.0084      1.26
# 205089  14:04:21  30.0  1.0117 -0.7031 -0.0021  0.0879  0.0094      1.29
# 205090  14:04:22  30.0  1.0078 -0.7031 -0.0021  0.0879  0.0084      1.86
# 205091  14:04:23  30.0  1.0078 -0.7031 -0.0021  0.0879  0.0084      1.45
# 205092  14:04:24  30.0  1.0039 -0.7031 -0.0021  0.0879  0.0084      1.71
#
#         下滑道偏差（L）  下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）    俯仰角率  下降率  RUDD位置  \
# 0          -0.58     -0.29     -3.17     -3.04     -3.28  0.0625   -5 -0.2617
# 1          -0.62     -0.36     -2.78     -2.78     -2.95 -0.0625   -9 -0.2578
# 2           0.26     -0.10     -3.06     -2.96     -3.18 -0.0625  -12 -0.2578
# 3          -0.21      0.13     -2.78     -2.78     -2.92 -0.0625   -4 -0.2578
# 4           0.00     -0.48     -2.94     -2.88     -3.09  0.0000   -3 -0.2578
# ...          ...       ...       ...       ...       ...     ...  ...     ...
# 205088      1.38      1.03      2.67      2.34      2.76 -0.0625    0 -0.2676
# 205089      1.66      0.40      2.48      2.60      2.56  0.0000    0 -0.2676
# 205090      1.82      1.03      2.22      2.70      2.29 -0.0625    8 -0.2617
# 205091      2.00      0.55      2.33      2.69      2.39  0.0000   14 -0.2617
# 205092      2.02      0.67      2.41      2.72      2.43  0.0000   15 -0.2637
#
#          左油门杆位置   右油门杆位置
# 0       34.0137  34.0576
# 1       34.0137  34.0576
# 2       33.9697  34.0576
# 3       33.9697  34.0576
# 4       33.9697  34.0576
# ...         ...      ...
# 205088  33.9697  34.0576
# 205089  33.9697  34.0576
# 205090  33.9697  34.0576
# 205091  34.0137  34.0576
# 205092  34.0137  34.0576
#
# [205093 rows x 18 columns]

# %%
import matplotlib.pyplot as plt
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False

# %%
def drawHist(x):
    plt.figure(figsize=(10,8))
    dataAF.hist(column=x,bins=150,color='#9ACD32',grid=False)
    plt.xticks(font='Times New Roman',fontsize=12)
    plt.yticks(font='Times New Roman',fontsize=12)
    plt.savefig('Figures\\{}.pdf'.format(x))

# %%
drawHist('计算空速')
drawHist('G值')
drawHist('姿态')
drawHist('杆量')
drawHist('坡度')
drawHist('盘量')
drawHist('下滑道偏差（C）')
drawHist('下滑道偏差（L）')
drawHist('下滑道偏差（R）')
drawHist('航向道偏差（C）')
drawHist('航向道偏差（L）')
drawHist('航向道偏差（R）')
drawHist('俯仰角率')
drawHist('下降率')
drawHist('RUDD位置')
drawHist('左油门杆位置')
drawHist('右油门杆位置')
# Out:
# D:\TempS\ipykernel_30308\3269471885.py:2: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   plt.figure(figsize=(10,8))

# %%
def calculateRateTh(x):
    t=dataAF[x].diff()
    mean=t.mean()
    std=t.std()
    max=mean+3*std
    min=mean-3*std
    return min,max

# %%
def calculateTh(x):
    mean=dataAF[x].mean()
    std=dataAF[x].std()
    max=mean+3*std
    min=mean-3*std
    return min,max

# %%
RateTh=['姿态','坡度','RUDD位置','左油门杆位置','右油门杆位置']
Th=['G值','杆量','盘量','下滑道偏差（C）','下滑道偏差（L）','下滑道偏差（R）',
    '航向道偏差（C）','航向道偏差（L）','航向道偏差（R）','俯仰角率','下降率']

# %%
for i in RateTh:
    min,max=calculateRateTh(i)
    print(i,min,max)
# Out:
# 姿态 -0.1823728785192135 0.18236945078921915
# 坡度 -0.6673918000300177 0.6673918000300177
# RUDD位置 -0.06688924609154025 0.06688922658809789
# 左油门杆位置 -0.7397604532999682 0.7397604532999682
# 右油门杆位置 -0.7364677711308804 0.7364677711308804

# %%
for i in Th:
    min,max=calculateTh(i)
    print(i,min,max)
# Out:
# G值 0.9537159362101948 1.0635978346157227
# 杆量 -0.045490727710496254 0.044095951682060375
# 盘量 -0.061697333362055275 0.054986543622766275
# 下滑道偏差（C） -3.272516829802762 3.346957205632264
# 下滑道偏差（L） -3.088455218634214 3.147513401994933
# 下滑道偏差（R） -3.0607728912464105 3.1096427210309474
# 航向道偏差（C） -4.9660114773697135 4.740072025511289
# 航向道偏差（L） -4.952541392349814 4.725793916814326
# 航向道偏差（R） -4.961188798370152 4.756167466584085
# 俯仰角率 -0.269455167818758 0.2101911997652408
# 下降率 -1660.3728475810756 1660.7590236085364

# %% [markdown]
# 姿态 -0.1823728785192135 0.18236945078921915
# 坡度 -0.6673918000300177 0.6673918000300177
# RUDD位置 -0.06688924609154025 0.06688922658809789
# 左油门杆位置 -0.7397604532999682 0.7397604532999682
# 右油门杆位置 -0.7364677711308804 0.7364677711308804
#
# G值 0.9537159362101948 1.0635978346157227
# 杆量 -0.045490727710496254 0.044095951682060375
# 盘量 -0.061697333362055275 0.054986543622766275
# 下滑道偏差（C） -3.272516829802762 3.346957205632264
# 下滑道偏差（L） -3.088455218634214 3.147513401994933
# 下滑道偏差（R） -3.0607728912464105 3.1096427210309474
# 航向道偏差（C） -4.9660114773697135 4.740072025511289
# 航向道偏差（L） -4.952541392349814 4.725793916814326
# 航向道偏差（R） -4.961188798370152 4.756167466584085
# 俯仰角率 -0.269455167818758 0.2101911997652408
# 下降率 -1660.3728475810756 1660.7590236085364

# %%
def zitai(x):
    if x<=-0.1823728785192135 or x>=0.18236945078921915:
        return '异常'
    else:
        return '正常'


def podu(x):
    if x<=-0.6673918000300177 or x>=0.6673918000300177:
        return '异常'
    else:
        return '正常'


def rudd(x):
    if x<=-0.06688924609154025 or x>=0.06688922658809789:
        return '异常'
    else:
        return '正常'


def zuoyoumengan(x):
    if x<=-0.7397604532999682 or x>=0.7397604532999682:
        return '异常'
    else:
        return '正常'


def youyoumengan(x):
    if x<=-0.7364677711308804 or x>=0.7364677711308804:
        return '异常'
    else:
        return '正常'


def g(x):
    if x<=0.9537159362101948:
        return '失重'
    elif x>=1.0635978346157227:
        return '超重'
    else:
        return '正常'


def gangliang(x):
    if x<=-0.045490727710496254:
        return '拉杆过度'
    elif x>=0.044095951682060375:
        return '松杆（推杆）过度'
    else:
        return '正常'


def panliang(x):
    if x<=-0.061697333362055275:
        return '左旋过度'
    elif x>=0.054986543622766275:
        return '右旋过度'
    else:
        return '正常'


def xiahuadaoC(x):
    if x<=-3.272516829802762 or x>=3.346957205632264:
        return '异常C'
    else:
        return '正常'


def xiahuadaoL(x):
    if x<=-3.088455218634214 or x>=3.147513401994933:
        return '异常L'
    else:
        return '正常'


def xiahuadaoR(x):
    if x<=-3.0607728912464105 or x>=3.1096427210309474:
        return '异常R'
    else:
        return '正常'


def hangxiangdaoC(x):
    if x<=-4.9660114773697135 or x>=4.740072025511289:
        return '异常C'
    else:
        return '正常'


def hangxiangdaoL(x):
    if x<=-4.952541392349814 or x>=4.725793916814326:
        return '异常L'
    else:
        return '正常'


def hangxiangdaoR(x):
    if x<=-4.961188798370152 or x>=4.756167466584085:
        return '异常R'
    else:
        return '正常'


def fuyangjiaolv(x):
    if x<=-0.269455167818758 or x>=0.2101911997652408:
        return '异常'
    else:
        return '正常'


def xiajianglv(x):
    if x<=-1660.3728475810756 or x>=1660.7590236085364:
        return '异常'
    else:
        return '正常'

# %%
def System(data):
    data=FactorSelect(MaxFactor(data))
    data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
    data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
    data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
    data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
    data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
    data['失重超重情况']=data['G值'].apply(lambda x:g(x))
    data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
    data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
    data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
    data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
    data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
    data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
    data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
    data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
    data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
    data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
    return data

# %%
data1V=System(data1)
data2V=System(data2)
data3V=System(data3)
data4V=System(data4)
data5V=System(data5)
data6V=System(data6)
data7V=System(data7)
data8V=System(data8)
# Out:
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))
# D:\TempS\ipykernel_30308\2952877580.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['飞行姿态变化']=data['姿态'].diff().apply(lambda x:zitai(x))
# D:\TempS\ipykernel_30308\2952877580.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['坡度变化']=data['坡度'].diff().apply(lambda x:podu(x))
# D:\TempS\ipykernel_30308\2952877580.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['RUDD位置变化']=data['RUDD位置'].diff().apply(lambda x:rudd(x))
# D:\TempS\ipykernel_30308\2952877580.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['左油门杆位置变化']=data['左油门杆位置'].diff().apply(lambda x:zuoyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['右油门杆位置变化']=data['右油门杆位置'].diff().apply(lambda x:youyoumengan(x))
# D:\TempS\ipykernel_30308\2952877580.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['失重超重情况']=data['G值'].apply(lambda x:g(x))
# D:\TempS\ipykernel_30308\2952877580.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['杆量情况']=data['杆量'].apply(lambda x:gangliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['盘量情况']=data['盘量'].apply(lambda x:panliang(x))
# D:\TempS\ipykernel_30308\2952877580.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（C）情况']=data['下滑道偏差（C）'].apply(lambda x:xiahuadaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（L）情况']=data['下滑道偏差（L）'].apply(lambda x:xiahuadaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下滑道偏差（R）情况']=data['下滑道偏差（R）'].apply(lambda x:xiahuadaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（C）情况']=data['航向道偏差（C）'].apply(lambda x:hangxiangdaoC(x))
# D:\TempS\ipykernel_30308\2952877580.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（L）情况']=data['航向道偏差（L）'].apply(lambda x:hangxiangdaoL(x))
# D:\TempS\ipykernel_30308\2952877580.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['航向道偏差（R）情况']=data['航向道偏差（R）'].apply(lambda x:hangxiangdaoR(x))
# D:\TempS\ipykernel_30308\2952877580.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['俯仰角率情况']=data['俯仰角率'].apply(lambda x:fuyangjiaolv(x))
# D:\TempS\ipykernel_30308\2952877580.py:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['下降率情况']=data['下降率'].apply(lambda x:xiajianglv(x))

# %%
data1V
# Out:
#            具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0       5:32:48  30.0  1.0156 -0.3516 -0.0010  0.0879  0.0115     -0.49
# 1       5:32:49  30.0  1.0273 -0.3516 -0.0010  0.0879  0.0115     -0.47
# 2       5:32:50  30.0  1.0117 -0.3516 -0.0010  0.0879  0.0104      0.08
# 3       5:32:51  30.0  1.0273 -0.3516 -0.0010  0.0879  0.0104     -0.17
# 4       5:32:52  30.0  1.0156 -0.3516 -0.0010  0.0879  0.0115     -0.05
# ...         ...   ...     ...     ...     ...     ...     ...       ...
# 38667  16:17:27  30.0  1.0039 -0.1758 -0.0010 -0.4395  0.0073     -5.32
# 38668  16:17:28  30.0  1.0117 -0.1758 -0.0010 -0.4395  0.0073     -5.06
# 38669  16:17:29  30.0  1.0078 -0.1758 -0.0010 -0.4395  0.0073     -5.12
# 38670  16:17:30  30.0  1.0078 -0.1758 -0.0010 -0.4395  0.0073     -4.15
# 38671  16:17:31  30.0  1.0000 -0.1758 -0.0021 -0.4395  0.0073     -5.08
#
#        下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  \
# 0         -0.58     -0.29  ...    正常    正常          正常          正常
# 1         -0.62     -0.36  ...    正常    正常          正常          正常
# 2          0.26     -0.10  ...    正常    正常          正常          正常
# 3         -0.21      0.13  ...    正常    正常          正常          正常
# 4          0.00     -0.48  ...    正常    正常          正常          正常
# ...         ...       ...  ...   ...   ...         ...         ...
# 38667     -5.13     -2.12  ...    正常    正常         异常C         异常L
# 38668     -5.29     -2.10  ...    正常    正常         异常C         异常L
# 38669     -4.98     -1.85  ...    正常    正常         异常C         异常L
# 38670     -4.31     -1.41  ...    正常    正常         异常C         异常L
# 38671     -5.29     -2.12  ...    正常    正常         异常C         异常L
#
#        下滑道偏差（R）情况  航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0              正常          正常          正常          正常     正常    正常
# 1              正常          正常          正常          正常     正常    正常
# 2              正常          正常          正常          正常     正常    正常
# 3              正常          正常          正常          正常     正常    正常
# 4              正常          正常          正常          正常     正常    正常
# ...           ...         ...         ...         ...    ...   ...
# 38667          正常          正常          正常          正常     正常    正常
# 38668          正常          正常          正常          正常     正常    正常
# 38669          正常          正常          正常          正常     正常    正常
# 38670          正常          正常          正常          正常     正常    正常
# 38671          正常          正常          正常          正常     正常    正常
#
# [38672 rows x 34 columns]

# %%
data2V
# Out:
#            具体时间  计算空速      G值      姿态     杆量      坡度      盘量  下滑道偏差（C）  \
# 0      19:17:47  30.0  1.0273  0.0879 -0.001  0.7031  0.0063     -1.52
# 1      19:17:48  30.0  1.0352  0.0879 -0.001  0.7031  0.0063     -0.15
# 2      19:17:49  30.0  1.0469  0.0879 -0.001  0.6152  0.0063      0.00
# 3      19:17:50  30.0  1.0195  0.1318 -0.001  0.5273  0.0073      0.06
# 4      19:17:51  30.0  1.0313  0.1318 -0.001  0.5273  0.0063     -1.17
# ...         ...   ...     ...     ...    ...     ...     ...       ...
# 33491   4:36: 8  30.0  1.0078 -0.1318 -0.001  0.0879  0.0104      3.68
# 33492   4:36: 9  30.0  1.0156 -0.1318 -0.001  0.0879  0.0104      3.53
# 33493   4:36:10  30.0  1.0078 -0.1318 -0.001  0.0879  0.0104      3.50
# 33494   4:36:11  30.0  1.0039 -0.1318 -0.001  0.0879  0.0104      3.59
# 33495   4:36:12  30.0  1.0078 -0.1318 -0.001  0.0879  0.0104      3.49
#
#        下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  \
# 0         -1.37     -0.30  ...    正常    正常          正常          正常
# 1         -0.09     -0.04  ...    正常    正常          正常          正常
# 2         -0.04      0.62  ...    正常    正常          正常          正常
# 3         -0.37     -0.15  ...    正常    正常          正常          正常
# 4         -1.15      0.01  ...    正常    正常          正常          正常
# ...         ...       ...  ...   ...   ...         ...         ...
# 33491      3.54      2.03  ...    正常    正常         异常C         异常L
# 33492      3.58      2.00  ...    正常    正常         异常C         异常L
# 33493      3.45      2.20  ...    正常    正常         异常C         异常L
# 33494      3.69      1.96  ...    正常    正常         异常C         异常L
# 33495      3.54      1.70  ...    正常    正常         异常C         异常L
#
#        下滑道偏差（R）情况  航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0              正常          正常          正常          正常     正常    正常
# 1              正常          正常          正常          正常     正常    正常
# 2              正常          正常          正常          正常     正常    正常
# 3              正常          正常          正常          正常     正常    正常
# 4              正常          正常          正常          正常     正常    正常
# ...           ...         ...         ...         ...    ...   ...
# 33491          正常          正常          正常          正常     正常    正常
# 33492          正常          正常          正常          正常     正常    正常
# 33493          正常          正常          正常          正常     正常    正常
# 33494          正常          正常          正常          正常     正常    正常
# 33495          正常          正常          正常          正常     正常    正常
#
# [33496 rows x 34 columns]

# %%
data3V
# Out:
#           具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0      6:17:47  30.0  1.0078 -0.0879 -0.0010  0.2637  0.0104      0.85
# 1      6:17:48  30.0  1.0273 -0.0879 -0.0010  0.2637  0.0104     -0.28
# 2      6:17:49  30.0  1.0313 -0.0879 -0.0010  0.1758  0.0094      1.71
# 3      6:17:50  30.0  1.0313 -0.0879 -0.0010  0.1758  0.0104      0.34
# 4      6:17:51  30.0  1.0195 -0.0879 -0.0010  0.1758  0.0104      1.34
# ...        ...   ...     ...     ...     ...     ...     ...       ...
# 9965   9: 3:55  30.0  1.0078  0.0000 -0.0021  0.1758  0.0084     -1.92
# 9966   9: 3:56  30.0  1.0078  0.0439 -0.0021  0.1758  0.0084     -2.60
# 9967   9: 3:57  30.0  1.0039  0.0439 -0.0021  0.1758  0.0094     -2.74
# 9968   9: 3:58  30.0  1.0078  0.0439 -0.0021  0.1758  0.0084     -2.30
# 9969   9: 3:59  30.0  1.0117  0.0000 -0.0021  0.1758  0.0084     -2.10
#
#       下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  下滑道偏差（R）情况  \
# 0         1.49     -0.72  ...    正常    正常          正常          正常          正常
# 1        -0.19      0.37  ...    正常    正常          正常          正常          正常
# 2         1.90     -0.23  ...    正常    正常          正常          正常          正常
# 3         0.96      0.52  ...    正常    正常          正常          正常          正常
# 4         0.84     -0.56  ...    正常    正常          正常          正常          正常
# ...        ...       ...  ...   ...   ...         ...         ...         ...
# 9965     -2.09     -2.10  ...    正常    正常          正常          正常          正常
# 9966     -2.85     -2.42  ...    正常    正常          正常          正常          正常
# 9967     -2.71     -2.61  ...    正常    正常          正常          正常          正常
# 9968     -2.36     -2.20  ...    正常    正常          正常          正常          正常
# 9969     -2.12     -2.91  ...    正常    正常          正常          正常          正常
#
#       航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0             正常          正常          正常     正常    正常
# 1             正常          正常          正常     正常    正常
# 2             正常          正常          正常     正常    正常
# 3             正常          正常          正常     正常    正常
# 4             正常          正常          正常     正常    正常
# ...          ...         ...         ...    ...   ...
# 9965          正常          正常          正常     正常    正常
# 9966          正常          正常          正常     正常    正常
# 9967          正常          正常          正常     正常    正常
# 9968          正常          正常          正常     正常    正常
# 9969          正常          正常          正常     正常    正常
#
# [9970 rows x 34 columns]

# %%
data4V
# Out:
#            具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0      10:34:26  30.0  1.0313 -0.2197 -0.0010  0.0879  0.0115     -4.94
# 1      10:34:27  30.0  1.0273 -0.2197 -0.0010  0.0879  0.0115     -2.50
# 2      10:34:28  30.0  1.0234 -0.2197 -0.0010  0.0879  0.0115     -0.52
# 3      10:34:29  30.0  1.0273 -0.2197 -0.0010  0.0879  0.0115     -0.01
# 4      10:34:30  30.0  1.0156 -0.2197 -0.0010  0.0879  0.0115     -1.21
# ...         ...   ...     ...     ...     ...     ...     ...       ...
# 10474  13:29:03  30.0  1.0078  0.0000 -0.0021  0.0000  0.0063     -0.27
# 10475  13:29:04  30.0  1.0117  0.0000 -0.0010  0.0000  0.0073     -0.60
# 10476  13:29:05  30.0  1.0078  0.0000 -0.0021  0.0000  0.0063     -0.13
# 10477  13:29:06  30.0  1.0039  0.0000 -0.0021  0.0000  0.0063     -0.23
# 10478  13:29:07  30.0  1.0039  0.0000 -0.0010  0.0000  0.0063     -0.33
#
#        下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  \
# 0         -5.39     -0.79  ...    正常    正常         异常C         异常L
# 1         -2.28     -1.44  ...    正常    正常          正常          正常
# 2         -0.17     -2.34  ...    正常    正常          正常          正常
# 3         -0.43     -3.00  ...    正常    正常          正常          正常
# 4         -1.29     -2.70  ...    正常    正常          正常          正常
# ...         ...       ...  ...   ...   ...         ...         ...
# 10474     -0.30      0.15  ...    正常    正常          正常          正常
# 10475     -0.59     -0.37  ...    正常    正常          正常          正常
# 10476     -0.44     -0.14  ...    正常    正常          正常          正常
# 10477     -0.23      0.10  ...    正常    正常          正常          正常
# 10478     -0.31     -0.14  ...    正常    正常          正常          正常
#
#        下滑道偏差（R）情况  航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0              正常          正常          正常          正常     正常    正常
# 1              正常          正常          正常          正常     正常    正常
# 2              正常          正常          正常          正常     正常    正常
# 3              正常          正常          正常          正常     正常    正常
# 4              正常          正常          正常          正常     正常    正常
# ...           ...         ...         ...         ...    ...   ...
# 10474          正常          正常          正常          正常     正常    正常
# 10475          正常          正常          正常          正常     正常    正常
# 10476          正常          正常          正常          正常     正常    正常
# 10477          正常          正常          正常          正常     正常    正常
# 10478          正常          正常          正常          正常     正常    正常
#
# [10479 rows x 34 columns]

# %%
data5V
# Out:
#            具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0       1:11: 0  30.0  1.0352 -0.5273 -0.0021  0.0000  0.0104      2.71
# 1       1:11: 1  30.0  1.0352 -0.5713 -0.0021  0.0000  0.0104      1.40
# 2       1:11: 2  30.0  1.0352 -0.6152 -0.0021  0.0000  0.0104      3.65
# 3       1:11: 3  30.0  1.0195 -0.7031 -0.0021  0.0000  0.0104      4.08
# 4       1:11: 4  30.0  1.0273 -0.7471 -0.0021  0.0000  0.0104      4.05
# ...         ...   ...     ...     ...     ...     ...     ...       ...
# 47552  14:23:46  30.0  1.0156 -0.1758 -0.0010  0.3516  0.0094      0.16
# 47553  14:23:47  30.0  1.0039 -0.1758 -0.0010  0.3516  0.0094      0.07
# 47554  14:23:48  30.0  1.0039 -0.1758 -0.0010  0.3516  0.0094     -0.06
# 47555  14:23:49  30.0  1.0078 -0.1758 -0.0010  0.3516  0.0094     -0.21
# 47556  14:23:50  30.0  1.0078 -0.1758 -0.0010  0.3516  0.0094     -0.04
#
#        下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  \
# 0          2.58      0.75  ...    正常    正常          正常          正常
# 1          1.17     -0.88  ...    正常    正常          正常          正常
# 2          3.50      4.06  ...    正常    正常         异常C         异常L
# 3          4.24      3.29  ...    正常    正常         异常C         异常L
# 4          4.12      2.93  ...    正常    正常         异常C         异常L
# ...         ...       ...  ...   ...   ...         ...         ...
# 47552     -0.09      0.04  ...    正常    正常          正常          正常
# 47553      0.18      0.06  ...    正常    正常          正常          正常
# 47554      0.04     -0.12  ...    正常    正常          正常          正常
# 47555      0.27     -0.02  ...    正常    正常          正常          正常
# 47556     -0.07      0.00  ...    正常    正常          正常          正常
#
#        下滑道偏差（R）情况  航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0              正常          正常          正常          正常     正常    正常
# 1              正常          正常          正常          正常     正常    正常
# 2             异常R          正常          正常          正常     正常    正常
# 3             异常R          正常          正常          正常     正常    正常
# 4              正常          正常          正常          正常     正常    正常
# ...           ...         ...         ...         ...    ...   ...
# 47552          正常          正常          正常          正常     正常    正常
# 47553          正常          正常          正常          正常     正常    正常
# 47554          正常          正常          正常          正常     正常    正常
# 47555          正常          正常          正常          正常     正常    正常
# 47556          正常          正常          正常          正常     正常    正常
#
# [47557 rows x 34 columns]

# %%
data6V
# Out:
#            具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0      14:23:51  30.0  1.0039 -0.1758 -0.0010  0.3516  0.0094      0.05
# 1      17:01:50  30.0  1.0117 -0.8789 -0.0010  0.4395  0.0063      3.22
# 2      17:01:51  30.0  1.0156 -0.7910 -0.0010  0.4395  0.0063      3.67
# 3      17:01:52  30.0  1.0117 -0.7031 -0.0010  0.4395  0.0052      3.15
# 4      17:01:53  30.0  1.0313 -0.6152 -0.0010  0.4395  0.0052      4.30
# ...         ...   ...     ...     ...     ...     ...     ...       ...
# 50466   7: 3:11  30.0  1.0156 -0.1318 -0.0021  0.0879  0.0125      2.32
# 50467   7: 3:12  30.0  1.0078 -0.1318 -0.0021  0.0879  0.0125      2.12
# 50468   7: 3:13  30.0  1.0078 -0.1318 -0.0021  0.0879  0.0125      2.17
# 50469   7: 3:14  30.0  1.0078 -0.1318 -0.0021  0.0879  0.0125      2.29
# 50470   7: 3:15  30.0  1.0078 -0.1318 -0.0021  0.0879  0.0125      2.29
#
#        下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  \
# 0         -0.17     -0.05  ...    正常    正常          正常          正常
# 1          3.21      0.96  ...    正常    正常          正常         异常L
# 2          3.60      0.98  ...    正常    正常         异常C         异常L
# 3          3.27      0.99  ...    正常    正常          正常         异常L
# 4          4.37      1.27  ...    正常    正常         异常C         异常L
# ...         ...       ...  ...   ...   ...         ...         ...
# 50466      2.30      2.32  ...    正常    正常          正常          正常
# 50467      2.08      2.48  ...    正常    正常          正常          正常
# 50468      2.12      2.50  ...    正常    正常          正常          正常
# 50469      2.28      2.63  ...    正常    正常          正常          正常
# 50470      2.22      2.44  ...    正常    正常          正常          正常
#
#        下滑道偏差（R）情况  航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0              正常          正常          正常          正常     正常    正常
# 1              正常          正常          正常         异常R     正常    正常
# 2              正常          正常          正常         异常R     正常    正常
# 3              正常          正常          正常         异常R     正常    正常
# 4              正常          正常          正常         异常R     正常    正常
# ...           ...         ...         ...         ...    ...   ...
# 50466          正常          正常          正常          正常     正常    正常
# 50467          正常          正常          正常          正常     正常    正常
# 50468          正常          正常          正常          正常     正常    正常
# 50469          正常          正常          正常          正常     正常    正常
# 50470          正常          正常          正常          正常     正常    正常
#
# [50471 rows x 34 columns]

# %%
data7V
# Out:
#           具体时间  计算空速      G值      姿态     杆量      坡度      盘量  下滑道偏差（C）  \
# 0      8:43:26  30.0  1.0195 -0.3955 -0.001  0.4395  0.0000     -0.20
# 1      8:43:27  30.0  1.0195 -0.3076 -0.001  0.4395  0.0000      2.51
# 2      8:43:28  30.0  1.0156 -0.2197 -0.001  0.4395  0.0000     -1.68
# 3      8:43:29  30.0  1.0430 -0.1758 -0.001  0.4395  0.0000     -1.54
# 4      8:43:30  30.0  1.0273 -0.1758 -0.001  0.3516  0.0000      0.49
# ...        ...   ...     ...     ...    ...     ...     ...       ...
# 6980  10:39:48  30.0  1.0078  0.0439 -0.001  0.1758  0.0084      0.71
# 6981  10:39:49  30.0  1.0039  0.0439 -0.001  0.1758  0.0084      0.83
# 6982  10:39:50  30.0  1.0078  0.0439 -0.001  0.1758  0.0084      0.42
# 6983  10:39:51  30.0  1.0000  0.0439 -0.001  0.1758  0.0084     -0.39
# 6984  10:39:52  30.0  1.0039  0.0439 -0.001  0.1758  0.0084      0.64
#
#       下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  下滑道偏差（R）情况  \
# 0        -0.04     -3.30  ...    正常    正常          正常          正常         异常R
# 1         1.76     -3.83  ...    正常    正常          正常          正常         异常R
# 2        -1.54     -2.81  ...    正常    正常          正常          正常          正常
# 3        -1.62     -3.42  ...    正常    正常          正常          正常         异常R
# 4         0.28     -2.18  ...    正常    正常          正常          正常          正常
# ...        ...       ...  ...   ...   ...         ...         ...         ...
# 6980      0.60     -2.79  ...    正常    正常          正常          正常          正常
# 6981      0.58     -2.05  ...    正常    正常          正常          正常          正常
# 6982      0.67     -1.37  ...    正常    正常          正常          正常          正常
# 6983     -0.57     -1.52  ...    正常    正常          正常          正常          正常
# 6984      0.70     -1.97  ...    正常    正常          正常          正常          正常
#
#       航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0             正常          正常          正常     正常    正常
# 1             正常          正常          正常     正常    正常
# 2             正常          正常          正常     正常    正常
# 3             正常          正常          正常     正常    正常
# 4             正常          正常          正常     正常    正常
# ...          ...         ...         ...    ...   ...
# 6980          正常          正常          正常     正常    正常
# 6981          正常         异常L          正常     正常    正常
# 6982          正常         异常L          正常     正常    正常
# 6983          正常         异常L          正常     正常    正常
# 6984          正常         异常L          正常     正常    正常
#
# [6985 rows x 34 columns]

# %%
data8V
# Out:
#           具体时间  计算空速      G值      姿态      杆量      坡度      盘量  下滑道偏差（C）  \
# 0     11:59:59  30.0  1.0195 -0.3076 -0.0010  0.3516  0.0063     -1.35
# 1     12:00:00  30.0  1.0156 -0.3076 -0.0010  0.3516  0.0063     -0.80
# 2     12:00:01  30.0  1.0234 -0.3516 -0.0010  0.3516  0.0063     -1.37
# 3     12:00:02  30.0  1.0273 -0.3516 -0.0010  0.3516  0.0063      1.60
# 4     12:00:03  30.0  1.0156 -0.3516 -0.0010  0.3516  0.0063      1.22
# ...        ...   ...     ...     ...     ...     ...     ...       ...
# 7458  14:04:20  30.0  1.0078 -0.7031 -0.0021  0.0879  0.0084      1.26
# 7459  14:04:21  30.0  1.0117 -0.7031 -0.0021  0.0879  0.0094      1.29
# 7460  14:04:22  30.0  1.0078 -0.7031 -0.0021  0.0879  0.0084      1.86
# 7461  14:04:23  30.0  1.0078 -0.7031 -0.0021  0.0879  0.0084      1.45
# 7462  14:04:24  30.0  1.0039 -0.7031 -0.0021  0.0879  0.0084      1.71
#
#       下滑道偏差（L）  下滑道偏差（R）  ...  杆量情况  盘量情况  下滑道偏差（C）情况  下滑道偏差（L）情况  下滑道偏差（R）情况  \
# 0         0.06      1.29  ...    正常    正常          正常          正常          正常
# 1        -0.33     -1.90  ...    正常    正常          正常          正常          正常
# 2        -1.17      0.74  ...    正常    正常          正常          正常          正常
# 3         1.31     -1.47  ...    正常    正常          正常          正常          正常
# 4         1.05      2.70  ...    正常    正常          正常          正常          正常
# ...        ...       ...  ...   ...   ...         ...         ...         ...
# 7458      1.38      1.03  ...    正常    正常          正常          正常          正常
# 7459      1.66      0.40  ...    正常    正常          正常          正常          正常
# 7460      1.82      1.03  ...    正常    正常          正常          正常          正常
# 7461      2.00      0.55  ...    正常    正常          正常          正常          正常
# 7462      2.02      0.67  ...    正常    正常          正常          正常          正常
#
#       航向道偏差（C）情况  航向道偏差（L）情况  航向道偏差（R）情况 俯仰角率情况 下降率情况
# 0             正常          正常          正常     正常    正常
# 1             正常          正常          正常     正常    正常
# 2             正常          正常          正常     正常    正常
# 3             正常          正常          正常     正常    正常
# 4             正常          正常          正常     正常    正常
# ...          ...         ...         ...    ...   ...
# 7458          正常          正常          正常     正常    正常
# 7459          正常          正常          正常     正常    正常
# 7460          正常          正常          正常     正常    正常
# 7461          正常          正常          正常     正常    正常
# 7462          正常          正常          正常     正常    正常
#
# [7463 rows x 34 columns]
