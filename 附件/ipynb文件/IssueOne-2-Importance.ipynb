# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv('Data\\First\\NNew\\1-2D.csv')
data
# Out:
#        Unnamed: 0  海拔高度  下降率  无线电高度  计算空速     地速  起落架  空地电门0.2秒  空地电门0.4秒  \
# 0               0   425  -37     -8  30.0  10.75  1.0         0         0
# 1               1   423  -37     -8  30.0  10.75  1.0         0         0
# 2               2   422  -18     -9  30.0  10.75  1.0         0         0
# 3               3   422    3     -9  30.0  10.75  1.0         0         0
# 4               4   423    8     -9  30.0  10.75  1.0         0         0
# ...           ...   ...  ...    ...   ...    ...  ...       ...       ...
# 33481       33491   106   -2     -8  30.0   0.50  1.0         0         0
# 33482       33492   106   -4     -8  30.0   0.50  1.0         0         0
# 33483       33493   106   -4     -8  30.0   0.50  1.0         0         0
# 33484       33494   106   -3     -8  30.0   0.50  1.0         0         0
# 33485       33495   106   -2     -8  30.0   0.50  1.0         0         0
#
#        空地电门0.6秒  ...  右发油门杆位置（角度）  右发油门杆位置（角度）.1  RUDD位置  下滑道偏差（C）  下滑道偏差（L）  \
# 0             0  ...      34.5850        34.5850 -0.2539     -1.52     -1.37
# 1             0  ...      34.5850        34.5850 -0.2539     -0.15     -0.09
# 2             0  ...      34.5850        34.5850 -0.2539      0.00     -0.04
# 3             0  ...      34.5850        34.5850 -0.2539      0.06     -0.37
# 4             0  ...      34.5850        34.5850 -0.2539     -1.17     -1.15
# ...         ...  ...          ...            ...     ...       ...       ...
# 33481         0  ...      34.1016        34.1016 -0.2480      3.68      3.54
# 33482         0  ...      34.1016        34.1016 -0.2480      3.53      3.58
# 33483         0  ...      34.1016        34.1016 -0.2539      3.50      3.45
# 33484         0  ...      34.1016        34.1016 -0.2539      3.59      3.69
# 33485         0  ...      34.1016        34.1016 -0.2617      3.49      3.54
#
#        下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）    俯仰角率
# 0         -0.30      4.01      3.56      4.20  0.1250
# 1         -0.04      3.22      3.37      3.14 -0.0625
# 2          0.62      3.95      3.70      4.02 -0.1250
# 3         -0.15      3.42      2.42      3.41 -0.0625
# 4          0.01      3.60      3.62      3.54  0.0625
# ...         ...       ...       ...       ...     ...
# 33481      2.03      4.06      0.91      4.14  0.0000
# 33482      2.00      4.11      0.94      4.18 -0.0625
# 33483      2.20      4.10      0.98      4.18  0.0000
# 33484      1.96      4.01      1.06      4.07  0.0000
# 33485      1.70      4.08      1.10      4.21 -0.0625
#
# [33486 rows x 58 columns]

# %% [markdown]
# # 数据标准化

# %%
import sklearn.preprocessing as sp
StandardTransform = data.loc[:,~data.columns.isin(['Unnamed: 0'])]
StandardTransform
# Out:
#        海拔高度  下降率  无线电高度  计算空速     地速  起落架  空地电门0.2秒  空地电门0.4秒  空地电门0.6秒  \
# 0       425  -37     -8  30.0  10.75  1.0         0         0         0
# 1       423  -37     -8  30.0  10.75  1.0         0         0         0
# 2       422  -18     -9  30.0  10.75  1.0         0         0         0
# 3       422    3     -9  30.0  10.75  1.0         0         0         0
# 4       423    8     -9  30.0  10.75  1.0         0         0         0
# ...     ...  ...    ...   ...    ...  ...       ...       ...       ...
# 33481   106   -2     -8  30.0   0.50  1.0         0         0         0
# 33482   106   -4     -8  30.0   0.50  1.0         0         0         0
# 33483   106   -4     -8  30.0   0.50  1.0         0         0         0
# 33484   106   -3     -8  30.0   0.50  1.0         0         0         0
# 33485   106   -2     -8  30.0   0.50  1.0         0         0         0
#
#        空地电门0.8秒  ...  右发油门杆位置（角度）  右发油门杆位置（角度）.1  RUDD位置  下滑道偏差（C）  下滑道偏差（L）  \
# 0             0  ...      34.5850        34.5850 -0.2539     -1.52     -1.37
# 1             0  ...      34.5850        34.5850 -0.2539     -0.15     -0.09
# 2             0  ...      34.5850        34.5850 -0.2539      0.00     -0.04
# 3             0  ...      34.5850        34.5850 -0.2539      0.06     -0.37
# 4             0  ...      34.5850        34.5850 -0.2539     -1.17     -1.15
# ...         ...  ...          ...            ...     ...       ...       ...
# 33481         0  ...      34.1016        34.1016 -0.2480      3.68      3.54
# 33482         0  ...      34.1016        34.1016 -0.2480      3.53      3.58
# 33483         0  ...      34.1016        34.1016 -0.2539      3.50      3.45
# 33484         0  ...      34.1016        34.1016 -0.2539      3.59      3.69
# 33485         0  ...      34.1016        34.1016 -0.2617      3.49      3.54
#
#        下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）    俯仰角率
# 0         -0.30      4.01      3.56      4.20  0.1250
# 1         -0.04      3.22      3.37      3.14 -0.0625
# 2          0.62      3.95      3.70      4.02 -0.1250
# 3         -0.15      3.42      2.42      3.41 -0.0625
# 4          0.01      3.60      3.62      3.54  0.0625
# ...         ...       ...       ...       ...     ...
# 33481      2.03      4.06      0.91      4.14  0.0000
# 33482      2.00      4.11      0.94      4.18 -0.0625
# 33483      2.20      4.10      0.98      4.18  0.0000
# 33484      1.96      4.01      1.06      4.07  0.0000
# 33485      1.70      4.08      1.10      4.21 -0.0625
#
# [33486 rows x 57 columns]

# %%
ListColumns=list(StandardTransform.columns)
ListColumns
# Out:
# ['海拔高度',
#  '下降率',
#  '无线电高度',
#  '计算空速',
#  '地速',
#  '起落架',
#  '空地电门0.2秒',
#  '空地电门0.4秒',
#  '空地电门0.6秒',
#  '空地电门0.8秒',
#  '空地电门1秒',
#  '着陆G值0.1秒',
#  '着陆G值0.2秒',
#  '着陆G值0.3秒',
#  '着陆G值0.4秒',
#  '着陆G值0.5秒',
#  '着陆G值0.6秒',
#  '着陆G值0.7秒',
#  '着陆G值0.8秒',
#  '着陆G值0.9秒',
#  '着陆G值1秒',
#  '姿态（俯仰角）',
#  '姿态（俯仰角）.1',
#  '姿态（俯仰角）.2',
#  '姿态（俯仰角）.3',
#  '姿态（俯仰角）.4',
#  '杆量',
#  '杆量.1',
#  '杆量.2',
#  '杆量.3',
#  '杆量.4',
#  '坡度（左负右正）',
#  '坡度（左负右正）.1',
#  '盘量',
#  '盘量.1',
#  '盘量.2',
#  '盘量.3',
#  '盘量.4',
#  '左侧发动机油门N1值',
#  '右侧发动机油门N1值',
#  '磁航向',
#  '风向',
#  '风速',
#  '是否接通了A/T',
#  '是否接通了任意侧的A/P',
#  '左发油门杆位置（角度）',
#  '左发油门杆位置（角度）.1',
#  '右发油门杆位置（角度）',
#  '右发油门杆位置（角度）.1',
#  'RUDD位置',
#  '下滑道偏差（C）',
#  '下滑道偏差（L）',
#  '下滑道偏差（R）',
#  '航向道偏差（C）',
#  '航向道偏差（L）',
#  '航向道偏差（R）',
#  '俯仰角率']

# %%
StandardTransformScaler = sp.StandardScaler()
StandardTransformScaler = StandardTransformScaler.fit(StandardTransform)
StandardTransform = StandardTransformScaler.transform(StandardTransform)
StandardTransform = pd.DataFrame(StandardTransform)
StandardTransform.columns = ListColumns
StandardTransform
# Out:
#            海拔高度       下降率     无线电高度      计算空速        地速       起落架  空地电门0.2秒  \
# 0     -3.727476 -0.085216 -4.357026 -5.428754 -4.723183  5.333965 -5.789788
# 1     -3.727721 -0.085216 -4.357026 -5.428754 -4.723183  5.333965 -5.789788
# 2     -3.727844 -0.042183 -4.360243 -5.428754 -4.723183  5.333965 -5.789788
# 3     -3.727844  0.005381 -4.360243 -5.428754 -4.723183  5.333965 -5.789788
# 4     -3.727721  0.016705 -4.360243 -5.428754 -4.723183  5.333965 -5.789788
# ...         ...       ...       ...       ...       ...       ...       ...
# 33481 -3.766590 -0.005944 -4.357026 -5.428754 -4.822607  5.333965 -5.789788
# 33482 -3.766590 -0.010474 -4.357026 -5.428754 -4.822607  5.333965 -5.789788
# 33483 -3.766590 -0.010474 -4.357026 -5.428754 -4.822607  5.333965 -5.789788
# 33484 -3.766590 -0.008209 -4.357026 -5.428754 -4.822607  5.333965 -5.789788
# 33485 -3.766590 -0.005944 -4.357026 -5.428754 -4.822607  5.333965 -5.789788
#
#        空地电门0.4秒  空地电门0.6秒  空地电门0.8秒  ...  右发油门杆位置（角度）  右发油门杆位置（角度）.1  \
# 0     -5.792864 -5.792864 -5.792864  ...    -3.673567      -3.673696
# 1     -5.792864 -5.792864 -5.792864  ...    -3.673567      -3.673696
# 2     -5.792864 -5.792864 -5.792864  ...    -3.673567      -3.673696
# 3     -5.792864 -5.792864 -5.792864  ...    -3.673567      -3.673696
# 4     -5.792864 -5.792864 -5.792864  ...    -3.673567      -3.673696
# ...         ...       ...       ...  ...          ...            ...
# 33481 -5.792864 -5.792864 -5.792864  ...    -3.750821      -3.750952
# 33482 -5.792864 -5.792864 -5.792864  ...    -3.750821      -3.750952
# 33483 -5.792864 -5.792864 -5.792864  ...    -3.750821      -3.750952
# 33484 -5.792864 -5.792864 -5.792864  ...    -3.750821      -3.750952
# 33485 -5.792864 -5.792864 -5.792864  ...    -3.750821      -3.750952
#
#          RUDD位置  下滑道偏差（C）  下滑道偏差（L）  下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）  \
# 0      0.580430 -1.739761 -1.668883 -0.496749  3.325000  2.978815  3.473813
# 1      0.580430 -0.241792 -0.161002 -0.153989  2.681001  2.823011  2.610491
# 2      0.580430 -0.077781 -0.102101  0.716095  3.276089  3.093618  3.327211
# 3      0.580430 -0.012177 -0.490851 -0.299003  2.844039  2.043990  2.830394
# 4      0.580430 -1.357068 -1.409716 -0.088074  2.990773  3.028017  2.936273
# ...         ...       ...       ...       ...       ...       ...       ...
# 33481  0.884125  3.945958  4.115254  2.574912  3.365759  0.805757  3.424945
# 33482  0.884125  3.781947  4.162375  2.535363  3.406519  0.830358  3.457524
# 33483  0.580430  3.749145  4.009231  2.799024  3.398367  0.863159  3.457524
# 33484  0.580430  3.847552  4.291958  2.482630  3.325000  0.928760  3.367934
# 33485  0.178935  3.738211  4.115254  2.139870  3.382063  0.961561  3.481957
#
#            俯仰角率
# 0      2.135202
# 1     -0.413099
# 2     -1.262532
# 3     -0.413099
# 4      1.285768
# ...         ...
# 33481  0.436335
# 33482 -0.413099
# 33483  0.436335
# 33484  0.436335
# 33485 -0.413099
#
# [33486 rows x 57 columns]

# %% [markdown]
# # 数据归一化

# %%
import sklearn.preprocessing as sp
MinMaxTransform = data.loc[:,~data.columns.isin(['Unnamed: 0'])]
MinMaxTransform
# Out:
#        海拔高度  下降率  无线电高度  计算空速     地速  起落架  空地电门0.2秒  空地电门0.4秒  空地电门0.6秒  \
# 0       425  -37     -8  30.0  10.75  1.0         0         0         0
# 1       423  -37     -8  30.0  10.75  1.0         0         0         0
# 2       422  -18     -9  30.0  10.75  1.0         0         0         0
# 3       422    3     -9  30.0  10.75  1.0         0         0         0
# 4       423    8     -9  30.0  10.75  1.0         0         0         0
# ...     ...  ...    ...   ...    ...  ...       ...       ...       ...
# 33481   106   -2     -8  30.0   0.50  1.0         0         0         0
# 33482   106   -4     -8  30.0   0.50  1.0         0         0         0
# 33483   106   -4     -8  30.0   0.50  1.0         0         0         0
# 33484   106   -3     -8  30.0   0.50  1.0         0         0         0
# 33485   106   -2     -8  30.0   0.50  1.0         0         0         0
#
#        空地电门0.8秒  ...  右发油门杆位置（角度）  右发油门杆位置（角度）.1  RUDD位置  下滑道偏差（C）  下滑道偏差（L）  \
# 0             0  ...      34.5850        34.5850 -0.2539     -1.52     -1.37
# 1             0  ...      34.5850        34.5850 -0.2539     -0.15     -0.09
# 2             0  ...      34.5850        34.5850 -0.2539      0.00     -0.04
# 3             0  ...      34.5850        34.5850 -0.2539      0.06     -0.37
# 4             0  ...      34.5850        34.5850 -0.2539     -1.17     -1.15
# ...         ...  ...          ...            ...     ...       ...       ...
# 33481         0  ...      34.1016        34.1016 -0.2480      3.68      3.54
# 33482         0  ...      34.1016        34.1016 -0.2480      3.53      3.58
# 33483         0  ...      34.1016        34.1016 -0.2539      3.50      3.45
# 33484         0  ...      34.1016        34.1016 -0.2539      3.59      3.69
# 33485         0  ...      34.1016        34.1016 -0.2617      3.49      3.54
#
#        下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）    俯仰角率
# 0         -0.30      4.01      3.56      4.20  0.1250
# 1         -0.04      3.22      3.37      3.14 -0.0625
# 2          0.62      3.95      3.70      4.02 -0.1250
# 3         -0.15      3.42      2.42      3.41 -0.0625
# 4          0.01      3.60      3.62      3.54  0.0625
# ...         ...       ...       ...       ...     ...
# 33481      2.03      4.06      0.91      4.14  0.0000
# 33482      2.00      4.11      0.94      4.18 -0.0625
# 33483      2.20      4.10      0.98      4.18  0.0000
# 33484      1.96      4.01      1.06      4.07  0.0000
# 33485      1.70      4.08      1.10      4.21 -0.0625
#
# [33486 rows x 57 columns]

# %%
MinMaxTransformScaler=sp.MinMaxScaler(feature_range=(0.002, 1))
MinMaxTransformScaler=MinMaxTransformScaler.fit(MinMaxTransform)
MinMaxTransform=MinMaxTransformScaler.transform(MinMaxTransform)
MinMaxTransform=pd.DataFrame(MinMaxTransform)
MinMaxTransform.columns=ListColumns
MinMaxTransform
# Out:
#            海拔高度       下降率     无线电高度   计算空速        地速  起落架  空地电门0.2秒  空地电门0.4秒  \
# 0      0.014020  0.635365  0.500023  0.002  0.020738  1.0     0.002     0.002
# 1      0.013963  0.635365  0.500023  0.002  0.020738  1.0     0.002     0.002
# 2      0.013935  0.638397  0.499779  0.002  0.020738  1.0     0.002     0.002
# 3      0.013935  0.641748  0.499779  0.002  0.020738  1.0     0.002     0.002
# 4      0.013963  0.642546  0.499779  0.002  0.020738  1.0     0.002     0.002
# ...         ...       ...       ...    ...       ...  ...       ...       ...
# 33481  0.004955  0.640950  0.500023  0.002  0.002446  1.0     0.002     0.002
# 33482  0.004955  0.640631  0.500023  0.002  0.002446  1.0     0.002     0.002
# 33483  0.004955  0.640631  0.500023  0.002  0.002446  1.0     0.002     0.002
# 33484  0.004955  0.640790  0.500023  0.002  0.002446  1.0     0.002     0.002
# 33485  0.004955  0.640950  0.500023  0.002  0.002446  1.0     0.002     0.002
#
#        空地电门0.6秒  空地电门0.8秒  ...  右发油门杆位置（角度）  右发油门杆位置（角度）.1    RUDD位置  \
# 0         0.002     0.002  ...     0.370310       0.370310  0.677403
# 1         0.002     0.002  ...     0.370310       0.370310  0.677403
# 2         0.002     0.002  ...     0.370310       0.370310  0.677403
# 3         0.002     0.002  ...     0.370310       0.370310  0.677403
# 4         0.002     0.002  ...     0.370310       0.370310  0.677403
# ...         ...       ...  ...          ...            ...       ...
# 33481     0.002     0.002  ...     0.363431       0.363431  0.681195
# 33482     0.002     0.002  ...     0.363431       0.363431  0.681195
# 33483     0.002     0.002  ...     0.363431       0.363431  0.677403
# 33484     0.002     0.002  ...     0.363431       0.363431  0.677403
# 33485     0.002     0.002  ...     0.363431       0.363431  0.672390
#
#        下滑道偏差（C）  下滑道偏差（L）  下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）      俯仰角率
# 0      0.445556  0.473370  0.490958  0.888681  0.845121  0.907073  0.491216
# 1      0.535448  0.558590  0.511042  0.812210  0.826729  0.804466  0.432510
# 2      0.545290  0.561919  0.562023  0.882873  0.858673  0.889649  0.412941
# 3      0.549227  0.539948  0.502545  0.831569  0.734770  0.830601  0.432510
# 4      0.468521  0.488017  0.514904  0.848993  0.850929  0.843185  0.471647
# ...         ...       ...       ...       ...       ...       ...       ...
# 33481  0.786752  0.800267  0.670938  0.893521  0.588603  0.901265  0.452078
# 33482  0.776910  0.802930  0.668621  0.898361  0.591507  0.905137  0.432510
# 33483  0.774941  0.794275  0.684070  0.897393  0.595379  0.905137  0.452078
# 33484  0.780847  0.810254  0.665531  0.888681  0.603123  0.894489  0.452078
# 33485  0.774285  0.800267  0.645447  0.895457  0.606995  0.908041  0.432510
#
# [33486 rows x 57 columns]

# %% [markdown]
# # PCA&层次聚类

# %%
import matplotlib.pyplot as plt

# %%
from sklearn.decomposition import PCA

pca = PCA()
pca.fit(StandardTransform)
evr = pca.explained_variance_ratio_

plt.figure(figsize=(12, 5))
plt.plot(range(0, len(evr)), evr.cumsum(), marker="d", linestyle="-")
plt.xlabel("Number of components",font='Times New Roman',fontsize=13)
plt.ylabel("Cumulative explained variance",font='Times New Roman',fontsize=13)
plt.xticks(font='Times New Roman',fontsize=12)
plt.yticks(font='Times New Roman',fontsize=12)
plt.tight_layout()
plt.savefig("Figures\\1-2 PCA Cumulative explained variance.pdf")

# %%
import scipy.cluster.hierarchy as sch
plt.figure(figsize=(12, 6))
dendrogram = sch.dendrogram(sch.linkage(StandardTransform.T, method = 'ward'))
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']=False
plt.xlabel('指标',fontsize=13)
plt.ylabel('离差平方和',fontsize=13)
plt.xticks(font='Times New Roman',fontsize=11)
plt.yticks(font='Times New Roman',fontsize=11)
plt.savefig("Figures\\1-2 层次聚类树状图.pdf")

# %% [markdown]
# 环境：风向、风速
# 人为操作：下降率、地速、起落架、G值、杆量、盘量、RUDD位置
# 飞机状态：姿态（俯仰角）、坡度、发动机N1值、磁航向、油门杆位置、下滑道偏差、航向道偏差、俯仰角率

# %%
IFactor=MinMaxTransform.loc[:,['风向','风速','下降率','地速','起落架',
                               '着陆G值0.1秒','着陆G值0.2秒','着陆G值0.3秒','着陆G值0.4秒','着陆G值0.5秒','着陆G值0.6秒','着陆G值0.7秒','着陆G值0.8秒','着陆G值0.9秒','着陆G值1秒',
                               '姿态（俯仰角）','姿态（俯仰角）.1','姿态（俯仰角）.2','姿态（俯仰角）.3','姿态（俯仰角）.4',
                               '杆量','杆量.1','杆量.2','杆量.3','杆量.4',
                               '坡度（左负右正）','坡度（左负右正）.1',
                               '盘量','盘量.1','盘量.2','盘量.3','盘量.4',
                               '左侧发动机油门N1值','右侧发动机油门N1值','磁航向',
                               '左发油门杆位置（角度）','左发油门杆位置（角度）.1','右发油门杆位置（角度）','右发油门杆位置（角度）.1',
                               'RUDD位置','下滑道偏差（C）','下滑道偏差（L）','下滑道偏差（R）',
                               '航向道偏差（C）','航向道偏差（L）','航向道偏差（R）',
                               '俯仰角率']]
IFactor
# Out:
#              风向        风速       下降率        地速  起落架  着陆G值0.1秒  着陆G值0.2秒  \
# 0      0.002000  0.002000  0.635365  0.020738  1.0  0.415474  0.377481
# 1      0.002000  0.002000  0.635365  0.020738  1.0  0.442639  0.230992
# 2      0.002000  0.002000  0.638397  0.020738  1.0  0.370581  0.487406
# 3      0.002000  0.002000  0.641748  0.020738  1.0  0.361602  0.304353
# 4      0.002000  0.002000  0.642546  0.020738  1.0  0.307731  0.423185
# ...         ...       ...       ...       ...  ...       ...       ...
# 33481  0.909607  0.522582  0.640950  0.002446  1.0  0.370581  0.395762
# 33482  0.909607  0.522582  0.640631  0.002446  1.0  0.352624  0.359199
# 33483  0.909607  0.522582  0.640631  0.002446  1.0  0.343645  0.350058
# 33484  0.909607  0.522582  0.640790  0.002446  1.0  0.361602  0.368340
# 33485  0.909607  0.522582  0.640950  0.002446  1.0  0.379559  0.386621
#
#        着陆G值0.3秒  着陆G值0.4秒  着陆G值0.5秒  ...  右发油门杆位置（角度）  右发油门杆位置（角度）.1  \
# 0      0.370141  0.340917  0.373030  ...     0.370310       0.370310
# 1      0.389491  0.386621  0.496777  ...     0.370310       0.370310
# 2      0.283067  0.350058  0.505012  ...     0.370310       0.370310
# 3      0.321767  0.423185  0.430891  ...     0.370310       0.370310
# 4      0.341117  0.432326  0.414419  ...     0.370310       0.370310
# ...         ...       ...       ...  ...          ...            ...
# 33481  0.331442  0.386621  0.447362  ...     0.363431       0.363431
# 33482  0.331442  0.395762  0.496777  ...     0.363431       0.363431
# 33483  0.360466  0.404903  0.463834  ...     0.363431       0.363431
# 33484  0.341117  0.368340  0.447362  ...     0.363431       0.363431
# 33485  0.331442  0.368340  0.472069  ...     0.363431       0.363431
#
#          RUDD位置  下滑道偏差（C）  下滑道偏差（L）  下滑道偏差（R）  航向道偏差（C）  航向道偏差（L）  航向道偏差（R）  \
# 0      0.677403  0.445556  0.473370  0.490958  0.888681  0.845121  0.907073
# 1      0.677403  0.535448  0.558590  0.511042  0.812210  0.826729  0.804466
# 2      0.677403  0.545290  0.561919  0.562023  0.882873  0.858673  0.889649
# 3      0.677403  0.549227  0.539948  0.502545  0.831569  0.734770  0.830601
# 4      0.677403  0.468521  0.488017  0.514904  0.848993  0.850929  0.843185
# ...         ...       ...       ...       ...       ...       ...       ...
# 33481  0.681195  0.786752  0.800267  0.670938  0.893521  0.588603  0.901265
# 33482  0.681195  0.776910  0.802930  0.668621  0.898361  0.591507  0.905137
# 33483  0.677403  0.774941  0.794275  0.684070  0.897393  0.595379  0.905137
# 33484  0.677403  0.780847  0.810254  0.665531  0.888681  0.603123  0.894489
# 33485  0.672390  0.774285  0.800267  0.645447  0.895457  0.606995  0.908041
#
#            俯仰角率
# 0      0.491216
# 1      0.432510
# 2      0.412941
# 3      0.432510
# 4      0.471647
# ...         ...
# 33481  0.452078
# 33482  0.432510
# 33483  0.452078
# 33484  0.452078
# 33485  0.432510
#
# [33486 rows x 47 columns]

# %%
IFactorEnv=IFactor.loc[:,['风向','风速']]
IFactorEnv
# Out:
#              风向        风速
# 0      0.002000  0.002000
# 1      0.002000  0.002000
# 2      0.002000  0.002000
# 3      0.002000  0.002000
# 4      0.002000  0.002000
# ...         ...       ...
# 33481  0.909607  0.522582
# 33482  0.909607  0.522582
# 33483  0.909607  0.522582
# 33484  0.909607  0.522582
# 33485  0.909607  0.522582
#
# [33486 rows x 2 columns]

# %%
IFactorPeo=IFactor.loc[:,['下降率','地速','起落架',
                          '着陆G值0.1秒','着陆G值0.2秒','着陆G值0.3秒','着陆G值0.4秒','着陆G值0.5秒','着陆G值0.6秒','着陆G值0.7秒','着陆G值0.8秒','着陆G值0.9秒','着陆G值1秒',
                          '杆量','杆量.1','杆量.2','杆量.3','杆量.4',
                          '盘量','盘量.1','盘量.2','盘量.3','盘量.4',
                          'RUDD位置',]]
IFactorPeo
# Out:
#             下降率        地速  起落架  着陆G值0.1秒  着陆G值0.2秒  着陆G值0.3秒  着陆G值0.4秒  \
# 0      0.635365  0.020738  1.0  0.415474  0.377481  0.370141  0.340917
# 1      0.635365  0.020738  1.0  0.442639  0.230992  0.389491  0.386621
# 2      0.638397  0.020738  1.0  0.370581  0.487406  0.283067  0.350058
# 3      0.641748  0.020738  1.0  0.361602  0.304353  0.321767  0.423185
# 4      0.642546  0.020738  1.0  0.307731  0.423185  0.341117  0.432326
# ...         ...       ...  ...       ...       ...       ...       ...
# 33481  0.640950  0.002446  1.0  0.370581  0.395762  0.331442  0.386621
# 33482  0.640631  0.002446  1.0  0.352624  0.359199  0.331442  0.395762
# 33483  0.640631  0.002446  1.0  0.343645  0.350058  0.360466  0.404903
# 33484  0.640790  0.002446  1.0  0.361602  0.368340  0.341117  0.368340
# 33485  0.640950  0.002446  1.0  0.379559  0.386621  0.331442  0.368340
#
#        着陆G值0.5秒  着陆G值0.6秒  着陆G值0.7秒  ...      杆量.1      杆量.2      杆量.3  \
# 0      0.373030  0.458180  0.515111  ...  0.259648  0.202042  0.203925
# 1      0.496777  0.458180  0.315608  ...  0.259648  0.202042  0.203925
# 2      0.505012  0.467668  0.391760  ...  0.259648  0.202042  0.203925
# 3      0.430891  0.515111  0.420226  ...  0.259648  0.202042  0.203925
# 4      0.414419  0.382028  0.429714  ...  0.259648  0.202042  0.203925
# ...         ...       ...       ...  ...       ...       ...       ...
# 33481  0.447362  0.477157  0.448691  ...  0.259648  0.202042  0.203925
# 33482  0.496777  0.467668  0.429714  ...  0.259648  0.202042  0.203925
# 33483  0.463834  0.458180  0.429714  ...  0.257864  0.202042  0.203925
# 33484  0.447362  0.467668  0.458180  ...  0.259648  0.202042  0.203925
# 33485  0.472069  0.467668  0.439203  ...  0.259648  0.202042  0.203925
#
#            杆量.4        盘量      盘量.1      盘量.2      盘量.3      盘量.4    RUDD位置
# 0      0.232308  0.591931  0.549052  0.514367  0.439579  0.567982  0.677403
# 1      0.232308  0.591931  0.549052  0.514367  0.439579  0.567982  0.677403
# 2      0.232308  0.591931  0.549052  0.514367  0.439579  0.567982  0.677403
# 3      0.232308  0.591931  0.549052  0.514367  0.441033  0.569050  0.677403
# 4      0.232308  0.591931  0.549052  0.514367  0.439579  0.567982  0.677403
# ...         ...       ...       ...       ...       ...       ...       ...
# 33481  0.232308  0.596101  0.553941  0.519875  0.445539  0.572362  0.681195
# 33482  0.232308  0.596101  0.553941  0.519875  0.445539  0.572362  0.681195
# 33483  0.230499  0.596101  0.553941  0.519875  0.445539  0.572362  0.677403
# 33484  0.232308  0.596101  0.553941  0.519875  0.445539  0.572362  0.677403
# 33485  0.230499  0.596101  0.553941  0.519875  0.445539  0.572362  0.672390
#
# [33486 rows x 24 columns]

# %%
IFactorMac=IFactor.loc[:,~IFactor.columns.isin(['风向','风速','下降率','地速','起落架',
                          '着陆G值0.1秒','着陆G值0.2秒','着陆G值0.3秒','着陆G值0.4秒','着陆G值0.5秒','着陆G值0.6秒','着陆G值0.7秒','着陆G值0.8秒','着陆G值0.9秒','着陆G值1秒',
                          '杆量','杆量.1','杆量.2','杆量.3','杆量.4',
                          '盘量','盘量.1','盘量.2','盘量.3','盘量.4','RUDD位置',])]
IFactorMac
# Out:
#         姿态（俯仰角）  姿态（俯仰角）.1  姿态（俯仰角）.2  姿态（俯仰角）.3  姿态（俯仰角）.4  坡度（左负右正）  \
# 0      0.061005   0.063574   0.063892   0.063733   0.063574  0.443051
# 1      0.063574   0.063574   0.063892   0.063733   0.063574  0.441441
# 2      0.063574   0.063574   0.063892   0.063733   0.063574  0.439831
# 3      0.063574   0.063574   0.066468   0.066302   0.066137  0.439831
# 4      0.066137   0.066137   0.066468   0.066302   0.066137  0.438223
# ...         ...        ...        ...        ...        ...       ...
# 33481  0.050748   0.050748   0.051000   0.050873   0.050748  0.431784
# 33482  0.050748   0.050748   0.051000   0.050873   0.050748  0.431784
# 33483  0.050748   0.050748   0.051000   0.050873   0.050748  0.431784
# 33484  0.050748   0.050748   0.051000   0.050873   0.050748  0.431784
# 33485  0.050748   0.050748   0.051000   0.050873   0.050748  0.431784
#
#        坡度（左负右正）.1  左侧发动机油门N1值  右侧发动机油门N1值       磁航向  ...  左发油门杆位置（角度）.1  \
# 0        0.442863    0.032316    0.040524  0.382177  ...       0.365598
# 1        0.442863    0.031103    0.039320  0.376077  ...       0.365598
# 2        0.441248    0.029891    0.039320  0.369976  ...       0.365598
# 3        0.439633    0.031103    0.040524  0.363598  ...       0.365598
# 4        0.439633    0.029891    0.040524  0.357220  ...       0.365598
# ...           ...         ...         ...       ...  ...            ...
# 33481    0.431560    0.032316    0.048951  0.911264  ...       0.359285
# 33482    0.431560    0.033529    0.050154  0.911264  ...       0.359917
# 33483    0.431560    0.033529    0.050154  0.911264  ...       0.359917
# 33484    0.431560    0.023827    0.022466  0.911264  ...       0.359285
# 33485    0.431560    0.002000    0.002000  0.911264  ...       0.359285
#
#        右发油门杆位置（角度）  右发油门杆位置（角度）.1  下滑道偏差（C）  下滑道偏差（L）  下滑道偏差（R）  航向道偏差（C）  \
# 0         0.370310       0.370310  0.445556  0.473370  0.490958  0.888681
# 1         0.370310       0.370310  0.535448  0.558590  0.511042  0.812210
# 2         0.370310       0.370310  0.545290  0.561919  0.562023  0.882873
# 3         0.370310       0.370310  0.549227  0.539948  0.502545  0.831569
# 4         0.370310       0.370310  0.468521  0.488017  0.514904  0.848993
# ...            ...            ...       ...       ...       ...       ...
# 33481     0.363431       0.363431  0.786752  0.800267  0.670938  0.893521
# 33482     0.363431       0.363431  0.776910  0.802930  0.668621  0.898361
# 33483     0.363431       0.363431  0.774941  0.794275  0.684070  0.897393
# 33484     0.363431       0.363431  0.780847  0.810254  0.665531  0.888681
# 33485     0.363431       0.363431  0.774285  0.800267  0.645447  0.895457
#
#        航向道偏差（L）  航向道偏差（R）      俯仰角率
# 0      0.845121  0.907073  0.491216
# 1      0.826729  0.804466  0.432510
# 2      0.858673  0.889649  0.412941
# 3      0.734770  0.830601  0.432510
# 4      0.850929  0.843185  0.471647
# ...         ...       ...       ...
# 33481  0.588603  0.901265  0.452078
# 33482  0.591507  0.905137  0.432510
# 33483  0.595379  0.905137  0.452078
# 33484  0.603123  0.894489  0.452078
# 33485  0.606995  0.908041  0.432510
#
# [33486 rows x 21 columns]

# %%
import copy
def ewm(data):
    label_need = data.keys()[:]
    data1 = data[label_need].values
    data2 = data1
    [m, n] = data2.shape
    data3 = copy.deepcopy(data2)
    p = copy.deepcopy(data3)
    for j in range(0, n):
        p[:, j] = data3[:, j] / sum(data3[:, j])
    e = copy.deepcopy(data3[0, :])
    for j in range(0, n):
        e[j] = -1 / np.log(m) * sum(p[:, j] * np.log(p[:, j]))
    w = (1 - e) / sum(1 - e)
    total = 0
    for sum_w in range(0, len(w)):
        total = total + w[sum_w]
    print(f'权重为：{w}，权重之和为：{total}')

# %%
ewm(IFactorEnv)
# Out:
# 权重为：[0.28385444 0.71614556]，权重之和为：1.0

# %%
ewm(IFactorPeo)
# Out:
# 权重为：[2.29561326e-03 1.12186143e-02 9.70464299e-01 1.50775753e-03
#  1.41550216e-03 1.91071857e-03 1.32464384e-03 7.63242544e-04
#  9.87378276e-04 1.09424295e-03 1.26210762e-03 8.87659194e-04
#  7.66643831e-04 3.30364700e-04 3.09921887e-04 6.07365066e-04
#  6.13793183e-04 3.84924169e-04 1.72377066e-04 2.79112816e-04
#  4.18690218e-04 7.08932761e-04 2.05874725e-04 7.02207624e-05]，权重之和为：0.9999999999999999

# %%
ewm(IFactorMac)
# Out:
# 权重为：[0.07862635 0.07861425 0.07864516 0.07860537 0.07861215 0.00984006
#  0.00992518 0.06501288 0.0624718  0.17164215 0.01730686 0.01730972
#  0.01699351 0.01699656 0.01095972 0.00926251 0.01127085 0.06199414
#  0.06147514 0.06194425 0.00249139]，权重之和为：0.9999999999999999
